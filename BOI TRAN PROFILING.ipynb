# %%
## From SQL to DataFrame Pandas
import pandas as pd
import pyodbc
from datetime import datetime

# %%
# sql_conn = pyodbc.connect('DRIVER={SQL Server Native Client 11.0}; \
#                             SERVER=192.168.1.208;\
#                             DATABASE=FinCrimeStaging; \
#                             UID=aml;\
#                             PWD=aml123;') 
# query = "SELECT * FROM FinCrimeStaging..GFT_Transactions"

# %%
columns = ['TransactionNumber'	
,'MethodofPayment'	
,'InstitutionCode'	
,'BranchCode'	
,'DepartmentCode'	
,'BookCreditInstitutionCode'	
,'BookCreditBranchCode'	
,'PaymentDate'	
,'ValueDate'	
,'Externalsequencenumber'	
,'Currencycode'	
,'Amount'	
,'TotalBillCharges'	
,'TotalDeductCharges'	
,'BeneficiaryType'	
,'FedwireProductCode'	
,'FedwireType'	
,'FedwireSubtype'	
,'ACHClass'	
,'ACHCode'	
,'SourceIndicator'	
,'ReferenceforBeneficiary'	
,'SendersReference'	
,'SendingbankType'	
,'SendingBankID'	
,'SendingBankName'	
,'SendingBankAddress1'	
,'SendingBankAddress2'	
,'SendingBankAddress3'	
,'Adviceaddress'	
,'Advicemethod'	
,'Swiftadvicemessagetype'	
,'ReceivingBankType'	
,'ReceivingBankID'	
,'ReceivingBankName'	
,'ReceivingBankAddress1'	
,'ReceivingBankAddress2'	
,'ReceivingBankAddress3'	
,'AdviceAddress'	
,'AdviceMethod1'	
,'SwiftAdviceMessageType1'	
,'OriginatorType'	
,'OriginatorID'	
,'OriginatorName'	
,'OriginatorAddress1'	
,'OriginatorAddress2'	
,'OriginatorAddress3'	
,'OriginatorAdviceAddress'	
,'OriginatorAdvicemethod'	
,'OriginatorSwiftadvicemessagetype'	
,'OriginatingBankType'	
,'OriginatingBankTypeID'	
,'OriginatingBankTypeName'	
,'OriginatingBankTypeAddress1'	
,'OriginatingBankTypeAddress2'	
,'OriginatingBankTypeAddress3'	
,'OriginatingBankTypeAdviceaddress'	
,'OriginatingBankTypeAdvicemethod'	
,'OriginatingBankTypeSwiftadvicemessagetype'	
,'InstructingBankType'	
,'InstructingBankTypeID'	
,'InstructingBankTypeName'	
,'InstructingBankTypeAddress1'	
,'InstructingBankTypeAddress2'	
,'InstructingBankTypeAddress3'	
,'InstructingBankTypeAdviceaddress'	
,'InstructingBankTypeAdvicemethod'	
,'InstructingBankTypeSwiftadvicemessagetype'	
,'BeneficiaryType1'	
,'BeneficiaryTypeID'	
,'BeneficiaryTypeName'	
,'BeneficiaryTypeAddress1'	
,'BeneficiaryTypeAddress2'	
,'BeneficiaryTypeAddress3'	
,'BeneficiaryTypeAdviceaddress'	
,'BeneficiaryTypeAdvicemethod'	
,'BeneficiaryTypeSwiftadvicemessagetype'	
,'BeneficiaryBankType'	
,'BeneficiaryBankTypeID'	
,'BeneficiaryBankTypeName'	
,'BeneficiaryBankTypeAddress1'	
,'BeneficiaryBankTypeAddress2'	
,'BeneficiaryBankTypeAddress3'	
,'BeneficiaryBankTypeAdviceaddress'	
,'BeneficiaryBankTypeAdvicemethod'	
,'BeneficiaryBankTypeSwiftadvicemessagetype'	
,'IntermediaryBankType'	
,'IntermediaryBankTypeID'	
,'IntermediaryBankTypeName'	
,'IntermediaryBankTypeAddress1'	
,'IntermediaryBankTypeAddress2'	
,'IntermediaryBankTypeAddress3'	
,'IntermediaryBankTypeAdviceaddress'	
,'IntermediaryBankTypeAdvicemethod'	
,'IntermediaryBankTypeSwiftadvicemessagetype'	
,'OriginatortoBeneficiaryInfoLine1'	
,'OriginatortoBeneficiaryInfoLine2'	
,'OriginatortoBeneficiaryInfoLine3'	
,'OriginatortoBeneficiaryInfoLine4'	
,'BanktoBankInfoLine1'	
,'BanktoBankInfoLine2'	
,'BanktoBankInfoLine3'	
,'BanktoBankInfoLine4'	
,'BanktoBankInfoLine5'	
,'BanktoBankInfoLine6'	
,'AdviceInformationLine1'	
,'AdviceInformationLine2'	
,'AdviceInformationLine3'	
,'AdviceInformationLine4'	
,'AdviceInformationLine5'	
,'AdviceInformationLine6'	
,'CHIPSISN'	
,'CHIPSOSN'	
,'CHIPSPSN'	
,'CHIPSRSN'	
,'CHIPSSSN'	
,'IMADCycleDate'	
,'IMADCalendarDate'	
,'IMADApplicationID'	
,'IMSN'	
,'IMADLtermID'	
,'IMADtime'	
,'OMADCycledate'	
,'OMADCalendarDate'	
,'OMADApplicationID'	
,'OMADLtermID'	
,'OMSN'	
,'OMADtime'	
,'CurrencyInstructedamountofincomingMt103'	
,'ExchangerateofincomingMt103'	
,'DetailofchargesofincomingMt103'	
,'SenderschargesofincomingMt1031'	
,'SenderschargesofincomingMt1032'	
,'SenderschargesofincomingMt1033'	
,'SenderschargesofincomingMt1034'	
,'ReceiverschargesofincomingMt103'	
,'TransactiontypecodeofincomingMt103'	
,'EntryDate'	
,'CompletionDate'	
,'CancelDate'	
,'TerminateDate'	
,'RolloverDate'	
,'PrintedDate'	
,'OFACCheckFlag'	
,'EDIflag'	
,'Prenotificationflag'	
,'TemplateName'	
,'TemplateVersionNumber'	
,'Memo'	
,'BeneficiaryCountryCode'	
,'BeneficiarysBankCountryCode'	
,'ReasonforPaymentLine1'	
,'ReasonforPaymentLine2'	
,'DebitAccountType'	
,'DebitAccountID'	
,'CreditAccountType'	
,'CreditAccountID'	
,'LocalAmount'	
,'PaidAmount'	
,'OverrideCharges'	
,'RemittanceCurrency'	
,'RemittanceAmount'	
,'RemittanceAppliedRate'	
,'RemittanceType'	
,'IntermediaryBank2Type'	
,'IntermediaryBank2ID'	
,'IntermediaryBank2Name'	
,'IntermediaryBank2address1'	
,'IntermediaryBank2address2'	
,'IntermediaryBank2address3'	
,'IntermediaryBank2adviceaddress'	
,'IntermediaryBank2advicemethod'	
,'IntermediaryBank2SwiftMT'	
,'BeneficiaryCountryCode1'	
,'BeneficiaryBankCountryCode'	
,'IntermediaryBankCountryCode'	
,'IntermediaryBank2CountryCode'	
,'OriginatorCountryCode'	
,'OriginatingBankCountryCode'	
,'CoverOriginatorType'	
,'APDOriginatorID'	
,'APDOriginatorIDName'	
,'APDOriginatorIDAddress1'	
,'APDOriginatorIDAddress2'	
,'APDOriginatorIDAddress3'	
,'APDOriginatingBankType'	
,'APDOriginatingBankID'	
,'APDOriginatingBankIDName'	
,'APDOriginatingBankIDAddress1'	
,'APDOriginatingBankIDAddress2'	
,'APDOriginatingBankIDAddress3'	
,'APDBeneficiaryType'	
,'APDBeneficiaryID'	
,'APDBeneficiaryIDName'
,'APDBeneficiaryIDAddress1'
,'APDBeneficiaryIDAddress2'	
,'APDBeneficiaryIDAddress3'
,'APDBeneficiaryBankType'	
,'APDBeneficiaryBankID'
,'APDBeneficiaryBankIDName'
,'APDBeneficiaryBankIDAddress1'
,'APDBeneficiaryBankIDAddress2'
,'APDBeneficiaryBankIDAddress3'	
,'APDIntermediaryBankType'	
,'APDIntermediaryID'
,'APDIntermediaryIDName'
,'APDIntermediaryIDAddress1'	
,'APDIntermediaryIDAddress2'
,'APDIntermediaryIDAddress3'
,'APDOriginatortoBeneficiaryInfoLine1'	
,'APDOriginatortoBeneficiaryInfoLine2'	
,'APDOriginatortoBeneficiaryInfoLine3'	
,'APDOriginatortoBeneficiaryInfoLine4'	
,'APDBanktoBankInfoLine1'	
,'APDBanktoBankInfoLine2'	
,'APDBanktoBankInfoLine3'	
,'APDBanktoBankInfoLine4'	
,'APDBanktoBankInfoLine5'	
,'APDBanktoBankInfoLine6'	
,'APDBeneficiaryCountryCode'	
,'APDBeneficiaryBankCountryCode'	
,'APDIntermediaryBankCountryCode'	
,'APDOriginatorCountryCode'	
,'APDOriginatingBankCountryCode'	
,'APDInstructedAmount'	
,'APDAPDFlag'	
,'InclearingCheckFlag'	
,'InstrumentCode'	
,'DomesticForeign'
,'RegEDisclosureDate'	
,'FXSpreadChargeAmt'	]

# %%
# df = pd.read_sql(query, sql_conn)

# %%
df=pd.read_csv(".\_11012018_11302018_GFT_Transactions.txt",names=columns,sep='~', na_values=["?"], header=None)

# column_to_be_date =  ["PaymentDate","ValueDate","IMADCycleDate","IMADCalendarDate","OMADCycledate","OMADCalendarDate","EntryDate",
#                       "CompletionDate","CancelDate","TerminateDate","RolloverDate","PrintedDate","RegEDisclosureDate"]

# %%
# df.dtypes

# %%
# df[column_to_be_date] = df[column_to_be_date].apply(pd.to_datetime)

# %%
# column_to_be_string = ["TransactionNumber"]
# df[column_to_be_string] = df[column_to_be_string].astype(str)

# %%
# convert_dict = {'TransactionNumber': int
# ,'MethodofPayment': float64
# ,'InstitutionCode':str
# ,'BranchCode'	:str
# ,'DepartmentCode':str
# ,'BookCreditInstitutionCode':str
# ,'BookCreditBranchCode':str
# ,'PaymentDate'	:  datetime
# ,'ValueDate'	:  datetime
# ,'Externalsequencenumber':str	
# ,'Currencycode'	:str
# ,'Amount': float	
# ,'TotalBillCharges'	:float64
# ,'TotalDeductCharges':float64	
# ,'BeneficiaryType'	:str	
# ,'FedwireProductCode'	:str	
# ,'FedwireType'	:str	
# ,'FedwireSubtype'	:str	
# ,'ACHClass'	:str	
# ,'ACHCode'	:str	
# ,'SourceIndicator'	:str	
# ,'ReferenceforBeneficiary'	:str	
# ,'SendersReference'	:str	
# ,'SendingbankType'	:str	
# ,'SendingBankID'	:str	
# ,'SendingBankName'	:str	
# ,'SendingBankAddress1'	:str	
# ,'SendingBankAddress2'	:str	
# ,'SendingBankAddress3'	:str	
# ,'Adviceaddress'	:str	
# ,'Advicemethod'	: int
# ,'Swiftadvicemessagetype'	:int
# ,'ReceivingBankType':str		
# ,'ReceivingBankID'	:str	
# ,'ReceivingBankName'	:str	
# ,'ReceivingBankAddress1'	:str	
# ,'ReceivingBankAddress2'	:str	
# ,'ReceivingBankAddress3'	:str	
# ,'AdviceAddress'	:str	
# ,'AdviceMethod1':	int
# ,'SwiftAdviceMessageType1'	:int
# ,'OriginatorType'	:str	
# ,'OriginatorID'	:str	
# ,'OriginatorName'	:str
# ,'OriginatorAddress1'	:str	
# ,'OriginatorAddress2'	:str	
# ,'OriginatorAddress3'	:str	
# ,'OriginatorAdviceAddress':str		
# ,'OriginatorAdvicemethod'	:int
# ,'OriginatorSwiftadvicemessagetype'	:int
# ,'OriginatingBankType'	:str	
# ,'OriginatingBankTypeID'	:str	
# ,'OriginatingBankTypeName'	:str	
# ,'OriginatingBankTypeAddress1'	:str	
# ,'OriginatingBankTypeAddress2'	:str	
# ,'OriginatingBankTypeAddress3'	:str
# ,'OriginatingBankTypeAdviceaddress'	:str	
# ,'OriginatingBankTypeAdvicemethod'	:int
# ,'OriginatingBankTypeSwiftadvicemessagetype'	:int
# ,'InstructingBankType'	:str	
# ,'InstructingBankTypeID'	:str	
# ,'InstructingBankTypeName'	:str	
# ,'InstructingBankTypeAddress1'	:str	
# ,'InstructingBankTypeAddress2'	:str	
# ,'InstructingBankTypeAddress3'	:str	
# ,'InstructingBankTypeAdviceaddress'	:str	
# ,'InstructingBankTypeAdvicemethod'	:int
# ,'InstructingBankTypeSwiftadvicemessagetype':int	
# ,'BeneficiaryType1'	:str	
# ,'BeneficiaryTypeID'	:str	
# ,'BeneficiaryTypeName'	:str	
# ,'BeneficiaryTypeAddress1'	:str	
# ,'BeneficiaryTypeAddress2'	:str	
# ,'BeneficiaryTypeAddress3'	:str	
# ,'BeneficiaryTypeAdviceaddress'	:str	
# ,'BeneficiaryTypeAdvicemethod'	:int
# ,'BeneficiaryTypeSwiftadvicemessagetype'	:int
# ,'BeneficiaryBankType'	:str	
# ,'BeneficiaryBankTypeID'	:str	
# ,'BeneficiaryBankTypeName'	:str	
# ,'BeneficiaryBankTypeAddress1'	:str	
# ,'BeneficiaryBankTypeAddress2'	:str	
# ,'BeneficiaryBankTypeAddress3'	:str	
# ,'BeneficiaryBankTypeAdviceaddress'	:str	
# ,'BeneficiaryBankTypeAdvicemethod'	:int
# ,'BeneficiaryBankTypeSwiftadvicemessagetype'	:int
# ,'IntermediaryBankType'	:str	
# ,'IntermediaryBankTypeID'	:str	
# ,'IntermediaryBankTypeName'	:str	
# ,'IntermediaryBankTypeAddress1'	:str	
# ,'IntermediaryBankTypeAddress2'	:str	
# ,'IntermediaryBankTypeAddress3'	:str	
# ,'IntermediaryBankTypeAdviceaddress' :str	
# ,'IntermediaryBankTypeAdvicemethod'	:int
# ,'IntermediaryBankTypeSwiftadvicemessagetype' :int	
# ,'OriginatortoBeneficiaryInfoLine1'	:str	
# ,'OriginatortoBeneficiaryInfoLine2'	:str	
# ,'OriginatortoBeneficiaryInfoLine3'	:str	
# ,'OriginatortoBeneficiaryInfoLine4'	:str	
# ,'BanktoBankInfoLine1'	:str	
# ,'BanktoBankInfoLine2'	:str	
# ,'BanktoBankInfoLine3'	:str	
# ,'BanktoBankInfoLine4'	:str	
# ,'BanktoBankInfoLine5'	:str	
# ,'BanktoBankInfoLine6'	:str	
# ,'AdviceInformationLine1'	:str	
# ,'AdviceInformationLine2'	:str	
# ,'AdviceInformationLine3'	:str	
# ,'AdviceInformationLine4'	:str	
# ,'AdviceInformationLine5'	:str	
# ,'AdviceInformationLine6'	:str	
# ,'CHIPSISN'	:str	
# ,'CHIPSOSN'	:str	
# ,'CHIPSPSN'	:str	
# ,'CHIPSRSN'	:str	
# ,'CHIPSSSN'	:str	
# ,'IMADCycleDate'	: datetime 
# ,'IMADCalendarDate'	: datetime 	
# ,'IMADApplicationID'	:str
# ,'IMSN'	:str
# ,'IMADLtermID'	:str
# ,'IMADtime'	: datetime
# ,'OMADCycledate'	: datetime
# ,'OMADCalendarDate'	:  datetime
# ,'OMADApplicationID' :str	
# ,'OMADLtermID'	:str
# ,'OMSN'	:str
# ,'OMADtime'	: datetime 
# ,'CurrencyInstructedamountofincomingMt103'	:str
# ,'ExchangerateofincomingMt103'	:str
# ,'DetailofchargesofincomingMt103'	:str
# ,'SenderschargesofincomingMt1031'	:str
# ,'SenderschargesofincomingMt1032'	:str
# ,'SenderschargesofincomingMt1033'	:str
# ,'SenderschargesofincomingMt1034'	:str
# ,'ReceiverschargesofincomingMt103'	:str
# ,'TransactiontypecodeofincomingMt103'	:str
# ,'EntryDate'	:  datetime
# ,'CompletionDate'	: datetime
# ,'CancelDate'	: datetime 
# ,'TerminateDate'	: datetime
# ,'RolloverDate' : datetime	
# ,'PrintedDate'	: datetime 
# ,'OFACCheckFlag'	:int
# ,'EDIflag'	:int
# ,'Prenotificationflag'	:int
# ,'TemplateName'	:str
# ,'TemplateVersionNumber'	:str
# ,'Memo'	:str
# ,'BeneficiaryCountryCode'	:str
# ,'BeneficiarysBankCountryCode'	:str
# ,'ReasonforPaymentLine1'	:str
# ,'ReasonforPaymentLine2'	:str
# ,'DebitAccountType'	:str
# ,'DebitAccountID'	:str
# ,'CreditAccountType'	:str
# ,'CreditAccountID'	:str
# ,'LocalAmount'	: float64
# ,'PaidAmount'	:float64
# ,'OverrideCharges':float64	
# ,'RemittanceCurrency'	:str
# ,'RemittanceAmount'	: float64
# ,'RemittanceAppliedRate'	:float64
# ,'RemittanceType' 	:str
# ,'IntermediaryBank2Type'	:str
# ,'IntermediaryBank2ID'	:str
# ,'IntermediaryBank2Name'	:str
# ,'IntermediaryBank2address1'	:str
# ,'IntermediaryBank2address2':str	
# ,'IntermediaryBank2address3'	:str
# ,'IntermediaryBank2adviceaddress'	:str
# ,'IntermediaryBank2advicemethod' :float64	
# ,'IntermediaryBank2SwiftMT'	:float64
# ,'BeneficiaryCountryCode1'	:str
# ,'BeneficiaryBankCountryCode'	:str
# ,'IntermediaryBankCountryCode'	:str
# ,'IntermediaryBank2CountryCode'	:str
# ,'OriginatorCountryCode'	:str
# ,'OriginatingBankCountryCode'	:str
# ,'CoverOriginatorType'	:str
# ,'APDOriginatorID'	:str
# ,'APDOriginatorIDName'	:str
# ,'APDOriginatorIDAddress1'	:str
# ,'APDOriginatorIDAddress2'	:str
# ,'APDOriginatorIDAddress3'	:str
# ,'APDOriginatingBankType'	:str
# ,'APDOriginatingBankID'	:str
# ,'APDOriginatingBankIDName'	:str
# ,'APDOriginatingBankIDAddress1'	:str
# ,'APDOriginatingBankIDAddress2'	:str
# ,'APDOriginatingBankIDAddress3'	:str
# ,'APDBeneficiaryType'	:str
# ,'APDBeneficiaryID'	:str
# ,'APDBeneficiaryIDName':str
# ,'APDBeneficiaryIDAddress1':str
# ,'APDBeneficiaryIDAddress2'	:str
# ,'APDBeneficiaryIDAddress3':str
# ,'APDBeneficiaryBankType':str	
# ,'APDBeneficiaryBankID':str
# ,'APDBeneficiaryBankIDName':str
# ,'APDBeneficiaryBankIDAddress1':str
# ,'APDBeneficiaryBankIDAddress2':str
# ,'APDBeneficiaryBankIDAddress3'	:str
# ,'APDIntermediaryBankType'	:str
# ,'APDIntermediaryID':str
# ,'APDIntermediaryIDName':str
# ,'APDIntermediaryIDAddress1'	:str
# ,'APDIntermediaryIDAddress2':str
# ,'APDIntermediaryIDAddress3':str
# ,'APDOriginatortoBeneficiaryInfoLine1'	:str
# ,'APDOriginatortoBeneficiaryInfoLine2'	:str
# ,'APDOriginatortoBeneficiaryInfoLine3'	:str
# ,'APDOriginatortoBeneficiaryInfoLine4'	:str
# ,'APDBanktoBankInfoLine1'	:str
# ,'APDBanktoBankInfoLine2'	:str
# ,'APDBanktoBankInfoLine3'	:str
# ,'APDBanktoBankInfoLine4'	:str
# ,'APDBanktoBankInfoLine5'	:str
# ,'APDBanktoBankInfoLine6'	:str
# ,'APDBeneficiaryCountryCode'	:str
# ,'APDBeneficiaryBankCountryCode':str	
# ,'APDIntermediaryBankCountryCode'	:str
# ,'APDOriginatorCountryCode'	:str
# ,'APDOriginatingBankCountryCode'	:str
# ,'APDInstructedAmount'	: float64
# ,'APDAPDFlag'	:int
# ,'InclearingCheckFlag':int	
# ,'InstrumentCode' :str	
# ,'DomesticForeign':str
# ,'RegEDisclosureDate'	 : datetime
# ,'FXSpreadChargeAmt'	:float64
# }
# df = df.astype(convert_dict) 
# print(df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-33a2e8d87df8> in <module>
#       1 convert_dict = {'TransactionNumber': int
# ----> 2 ,'MethodofPayment': float64
#       3 ,'InstitutionCode':str
#       4 ,'BranchCode'   :str
#       5 ,'DepartmentCode':str
#
# NameError: name 'float64' is not defined

# %%
df.head()
# Out:
#    TransactionNumber  MethodofPayment InstitutionCode BranchCode  \
# 0    201411180001312                3             BOI        NYC
# 1    201810100004189                3             BOI        NYC
# 2    201810170000818                5             BOI        NYC
# 3    201810220000184                3             BOI        NYC
# 4    201810220000973                3             BOI        NYC
#
#   DepartmentCode BookCreditInstitutionCode BookCreditBranchCode  \
# 0            MTO                       NaN                  NaN
# 1            MTO                       NaN                  NaN
# 2            MTO                       NaN                  NaN
# 3            MTO                       BOI                  NYC
# 4            MTO                       BOI                  NYC
#
#              PaymentDate              ValueDate  Externalsequencenumber  ...  \
# 0  2018-11-14 00:00:00.0  2018-11-14 00:00:00.0            1.811149e+12  ...
# ...

# %%
print(df.dtypes)
# Out:
# TransactionNumber                        int64
# MethodofPayment                          int64
# InstitutionCode                         object
# BranchCode                              object
# DepartmentCode                          object
# BookCreditInstitutionCode               object
# BookCreditBranchCode                    object
# PaymentDate                             object
# ValueDate                               object
# Externalsequencenumber                 float64
# Currencycode                            object
# Amount                                 float64
# TotalBillCharges                         int64
# TotalDeductCharges                       int64
# BeneficiaryType                         object
# FedwireProductCode                      object
# FedwireType                            float64
# FedwireSubtype                         float64
# ACHClass                                object
# ACHCode                                float64
# ...

# %%
import pandas_profiling
#Generate profile report using pandas_profiling
report = pandas_profiling.ProfileReport(df)

# %%
report.to_file(".\_11012018_11302018_GFT_Transactions.html")
