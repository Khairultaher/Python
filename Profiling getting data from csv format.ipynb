# %%
import pandas as pd

# %%
columns_1 = ['Reference number'
,'Transaction Code'
,'Transaction Amount'
,'Original Amount'
,'Currency code'
,'Transaction / Payment Date'
,'Debit Party Type'
,'Debit Party ID3.6'
,'Debit Party Name 2.5'
,'Debit Party Addr 13.6'
,'Debit Party Addr 23.6'
,'Debit Party Addr 33.6'
,'Debit Value Date'
,'Credit Party Type'
,'Credit Party ID 3.6'
,'Credit Party Name 2.5'
,'Credit Party Addr 13.6'
,'Credit Party Addr 23.6'
,'Credit Party Addr 33.6'
,'ATM#'
,'ATM Location'
,'Cash/No cash'
,'ATM transaction date / Posting date'
,'Check Number'
,'Transacting branch'
,'Transacting party name'
,'Originating Bank Information'
,'Bank to Bank Information'
,'3rd Party Type'
,'3rd Party ID3.6'
,'3rd Party Name2.5'
,'3rd Party Addr 13.6'
,'3rd Party Addr 23.6'
,'3rd Party Addr 33.6'
,'By-Order Party Type'
,'By-Order Party ID3.6'
,'By-Order Party Name2.5'
,'By-Order Party Addr 13.6'
,'By-Order Party Addr 23.6'
,'By-Order Party Addr 33.6'
,'Originating Party Type'
,'Originating Party ID3.6'
,'Originating Party Name 2.5'
,'Originating Party Addr 13.6'
,'Originating Party Addr 23.6'
,'Originating Party Addr 33.6'
,'CHIPS SSN'
,'FED IMAD'
,'FED OMAD'
,'Total of Bills'
,'Total of Deducts'
,'SWIFT 20'
,'SWIFT 21'
,'CHIPS credit advice'
,'CHIPS credit swift advice msg type'
,'SWIFT Incoming RefNo'
,'SWIFT Outgoing RefNo'
,'Queue Name'
,'Local Currency Original Amount 1.4.5'
,'Local Currency code 1.4.5'
,'Exchange rate'
,'Instructing Party Type'
,'Instructing Party ID3.6'
,'Instructing Party Name2.5'
,'Instructing Party Addr 13.6'
,'Instructing Party Addr 23.6'
,'Instructing Party Addr 33.6'
,'4th Party Type'
,'4th Party ID3.6'
,'4th Party Name2.5'
,'4th Party Addr 13.6'
,'4th Party Addr 23.6'
,'4th Party Addr 33.6'
,'5th Party Type'
,'5th Party ID3.6'
,'5th Party Name2.5'
,'5th Party Addr 13.6'
,'5th Party Addr 23.6'
,'5th Party Addr 33.6'
,'Override charges'
,'Additional Bills'
,'Additional Deducts'
,'CHIPS/FED raw message'
,'Institution code'
,'Fund/Stock Quantity 1.4.4'
,'Fund /CUSIP Number 1.4.4'
,'Fund/Stock Name1.4.4 3.6'
,'Debit Party Branch Code2'
,'Credit Party Branch Code2'
,'Record Type 2.2'
,'Create/Amend/Cancel   Date  2.2'
,'Transaction Notes 2.5'
,'Company Name3'
,'Stock Price3'
,'Stock Price Currency 3.0'
,'State Tax3'
,'Postage3'
,'Other Money3'
,'Bond Interest3'
,'Tax Withholding 3.0'
,'Blotter 3'
,'Registered Representative Number 3.0'
,'Cancel Code 3.0'
,'Cancel ID 3.0'
,'Settlement Process Date 3.0'
,'Original Settlement Date 3.0'
,'Tax Withholding Type Code 3.0'
,'Cover Beneficiary Address 14.1'
,'Cover Beneficiary Address 24.1'
,'Cover Beneficiary Address 34.1'
,'Cover Beneficiary Country 4.1'
,'Cover Originator to Beneficiary Information 14.1'
,'Cover Originator to Beneficiary Information 24.1'
,'Cover Originator to Beneficiary Information 34.1'
,'Cover Originator to Beneficiary Information 44.1'
,'Cover Bank to Bank Information 14.1'
,'Cover Bank to Bank Information 24.1'
,'Cover Bank to Bank Information 34.1'
,'Cover Bank to Bank Information 44.1'
,'Cover Bank to Bank Information 54.1'
,'Cover Bank to Bank Information 64.1'
,'Cover Payment Instructed Amount4.1'
,'Check Image Link 4.3'
,'Addnt Payment Info Type'
,'Addnt Payment Info']

columns_2 = ['column1','column2','column3','column4','column5','column6','column7','column8','column9','column10'
,'column11','column12','column13','column14','column15','column16','column17','column18','column19','column20'
,'column21','column22','column23','column24','column25','column26','column27','column28','column29','column30'
,'column31','column32','column33','column34','column35','column36','column37','column38','column39','column40'
,'column41','column42','column43','column44','column45','column46','column47','column48','column49','column50'
,'column51','column52','column53','column54','column55','column56','column57','column58','column59','column60'
,'column61','column62','column63','column64','column65','column66','column67','column68','column69','column70'
,'column71','column72','column73','column74','column75','column76','column77','column78','column79','column80'
,'column81','column82','column83','column84','column85','column86','column87','column88','column89','column90'
,'column91','column92','column93','column94','column95','column96','column97','column98','column99','column100'
,'column101','column102','column103','column104','column105','column106','column107','column108','column109','column110'
,'column111','column112','column113','column114','column115','column116','column117','column118','column119','column120'
,'column121','column122','column123','column124','column125','column126','column127','column128','column129','column130'
,'column131','column132','column133','column134','column135','column136','column137','column138','column139','column140'
,'column141','column142','column143','column144','column145','column146','column147','column148','column149','column150'
,'column151','column152','column153','column154','column155','column156','column157','column158','column159','column160'
,'column161','column162','column163','column164','column165','column166','column167','column168','column169','column170'
,'column171','column172','column173','column174','column175','column176','column177','column178','column179','column180'
,'column181','column182','column183','column184','column185','column186','column187','column188','column189','column190'
,'column191','column192','column193','column194','column195','column196','column197','column198','column199','column200'
,'column201','column202','column203','column204']

# %%
df=pd.read_csv(".\SAMPLE_TRANS_GIFTS_FORMAT.txt",names=columns_1,sep='~', na_values=["?"], header=None)

# convert column as per type
column_to_be_string = ["ATM#", "ATM Location","Cash/No cash","Check Number","Transacting party name","Bank to Bank Information"
                       ,"3rd Party Type","3rd Party ID3.6","3rd Party Name2.5","3rd Party Addr 13.6","3rd Party Addr 23.6","3rd Party Addr 33.6"
                       ,"By-Order Party Type","By-Order Party ID3.6","By-Order Party Name2.5","By-Order Party Addr 13.6","By-Order Party Addr 23.6"
                       ,"By-Order Party Addr 33.6","Originating Party Type","Originating Party ID3.6","Originating Party Addr 23.6","CHIPS SSN"
                       ,"FED IMAD","FED OMAD","SWIFT 20","SWIFT 21","CHIPS credit advice","CHIPS credit swift advice msg type","SWIFT Incoming RefNo"
                       ,"SWIFT Outgoing RefNo","Queue Name","Local Currency Original Amount 1.4.5","Cover Beneficiary Bank ID 4.1","Cover Beneficiary ID 4.1"
                       ,"Cover Originator Bank ID 4.1",
                      ]
df[column_to_be_string] = df[column_to_be_string].astype(str)

column_to_be_date =  ["ATM transaction date / Posting date","Transaction / Payment Date"]
df[column_to_be_date] = df[column_to_be_date].apply(pd.to_datetime)

# %%
df.head()
# Out:
#   Reference number Transaction Code  Transaction Amount  Original Amount  \
# 0  CFMSPACH4766498  CFSB_ODFI_ACH22                65.0             65.0
# 1  CFMSPACH4766499  CFSB_ODFI_ACH22                65.0             65.0
# 2  CFMSPACH4766500  CFSB_ODFI_ACH22                65.0             65.0
# 3  CFMSPACH4766583  CFSB_ODFI_ACH22              4000.0           4000.0
# 4  CFMSPACH4766585  CFSB_ODFI_ACH22              1152.0           1152.0
#
#   Currency code Transaction / Payment Date Debit Party Type Debit Party ID3.6  \
# 0           USD                 2019-03-26              NaN   CFSBCK715500314
# 1           USD                 2019-03-26              NaN   CFSBCK715500314
# 2           USD                 2019-03-26              NaN   CFSBCK715500314
# 3           USD                 2019-03-26              NaN   CFSBCK715100400
# 4           USD                 2019-03-26              NaN   CFSBCK715100400
#
#     Debit Party Name 2.5 Debit Party Addr 13.6  ...  \
# ...

# %%
import pandas_profiling
#Generate profile report using pandas_profiling
report = pandas_profiling.ProfileReport(df)

# %%
df = df.replace({pd.np.nan: None})
df = df.replace({pd.np.nan: None})
#covert profile report as html file
report.to_file(".\SAMPLE_TRANS_GIFTS_FORMAT.html")

# %%
#Add data to sql server..
# import pyodbc
# sql_conn = pyodbc.connect('DRIVER={SQL Server Native Client 11.0}; \
#                            SERVER=192.168.1.232\SRV19; \
#                            DATABASE=FinCrimeStaging; \
#                            Trusted_Connection=yes')

# %%
from sqlalchemy import create_engine
import urllib.parse 

connectionString = urllib.parse.quote_plus("DRIVER={SQL Server};SERVER=192.168.1.232\SRV19;DATABASE=FinCrimeStaging;UID=sa;PWD=aml123")
SQLALCHEMY_DATABASE_URI = "mssql+pyodbc:///?odbc_connect=%s" % connectionString 
engine = create_engine(SQLALCHEMY_DATABASE_URI, echo=True)

# %%
df = df.replace({pd.np.nan: None})
df.to_sql('SAMPLE_TRANS_GIFTS_FORMAT',engine,if_exists='replace',index=False)
# Out:
# 2019-04-11 17:16:13,903 INFO sqlalchemy.engine.base.Engine SELECT CAST(SERVERPROPERTY('ProductVersion') AS VARCHAR)
# 2019-04-11 17:16:13,904 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-11 17:16:13,906 INFO sqlalchemy.engine.base.Engine SELECT schema_name()
# 2019-04-11 17:16:13,907 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-11 17:16:13,909 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-04-11 17:16:13,909 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-11 17:16:13,911 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS NVARCHAR(60)) AS anon_1
# 2019-04-11 17:16:13,911 INFO sqlalchemy.engine.base.Engine ()
# ...
