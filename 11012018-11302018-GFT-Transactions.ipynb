# %%
import pandas as pd

# %%
df=pd.read_csv(".\_11012018_11302018_GFT_Transactions.txt",sep='~', na_values=["?"], header=None)
# Out:
# C:\Program Files\Python37\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (105,134,136,140,218,220,223) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#                0    1    2    3    4    5    6                      7    \
# 0  201411180001312    3  BOI  NYC  MTO  NaN  NaN  2018-11-14 00:00:00.0
# 1  201810100004189    3  BOI  NYC  MTO  NaN  NaN  2018-11-08 00:00:00.0
# 2  201810170000818    5  BOI  NYC  MTO  NaN  NaN  2018-11-01 00:00:00.0
# 3  201810220000184    3  BOI  NYC  MTO  BOI  NYC  2018-11-01 00:00:00.0
# 4  201810220000973    3  BOI  NYC  MTO  BOI  NYC  2018-11-02 00:00:00.0
#
#                      8             9    ... 221  222  223  224  225  226  227  \
# 0  2018-11-14 00:00:00.0  1.811149e+12  ... NaN  NaN  NaN  NaN  0.0  0.0  NaN
# 1  2018-11-08 00:00:00.0  1.810109e+12  ... NaN  NaN  NaN  NaN  0.0  0.0  NaN
# 2  2018-11-01 00:00:00.0  1.810179e+12  ... NaN  NaN  NaN  NaN  0.0  0.0  NaN
# 3  2018-11-01 00:00:00.0  1.810229e+12  ... NaN  NaN  NaN  NaN  0.0  0.0  NaN
# 4  2018-11-02 00:00:00.0  1.810229e+12  ... NaN  NaN  NaN  NaN  0.0  0.0  NaN
#
#    228 229  230
# 0    D NaN  NaN
# 1    D NaN  NaN
# ...

# %%
import pandas_profiling
#Generate profile report using pandas_profiling
report = pandas_profiling.ProfileReport(df)

# %%
report.to_file(".\_11012018_11302018_GFT_Transactions.html")

# %%
from sqlalchemy import create_engine
import urllib.parse 

connectionString = urllib.parse.quote_plus("DRIVER={SQL Server};SERVER=192.168.1.232\SRV19;DATABASE=FinCrimeStaging;UID=sa;PWD=aml123")
SQLALCHEMY_DATABASE_URI = "mssql+pyodbc:///?odbc_connect=%s" % connectionString 
engine = create_engine(SQLALCHEMY_DATABASE_URI, echo=True)

# %%
df = df.replace({pd.np.nan: None})
df.to_sql('_11012018_11302018_GFT_Transactions',engine,if_exists='replace',index=False)
# Out:
# 2019-04-30 16:44:48,353 INFO sqlalchemy.engine.base.Engine SELECT CAST(SERVERPROPERTY('ProductVersion') AS VARCHAR)
# 2019-04-30 16:44:48,354 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-30 16:44:48,356 INFO sqlalchemy.engine.base.Engine SELECT schema_name()
# 2019-04-30 16:44:48,356 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-30 16:44:48,359 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-04-30 16:44:48,360 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-30 16:44:48,362 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS NVARCHAR(60)) AS anon_1
# 2019-04-30 16:44:48,363 INFO sqlalchemy.engine.base.Engine ()
# ...
